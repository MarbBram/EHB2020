# %% [markdown]
# # Exploratory data analysis (EDA)
# ## Line plots
#
# Plotting the series is an important step in the analysis process since it gives you an overview of how the data actually looks and allows us to identify trends and patterns easily.
#
# You'll be plotting some line graphs using pandas .plot() method now.
#
# pandas as pd and matplotlib.pyplot as plt have been imported for you.

# %% [markdown]
# #### Create a line-plot from df for the columns cols, setting the title as "Environmental data". Label the X-Axis as "Time"

# %%
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("environmental.csv", index_col="timestamp", parse_dates=True)
cols = ["temperature", "humidity", "pressure"]

# %%
# Create a line plot
df[cols].plot(title="Environmental data")

# Label X-Axis
plt.xlabel("Time")

# Show plot
plt.show()

# %% [markdown]
# ### 2 Create the same plot again, but this time move "pressure" to the secondary Y-Axis.

# %% [markdown]
# ## Histogram Plot
#
# While it's important to know how the data looks, data distribution is equally important.
# You can do this for the environmental dataset by plotting histograms.
# pandas has been imported as pd, and matplotlib.pyplot as plt.

# %% [markdown]
# ### Task
# Plot 4 histograms (1 per category) from df with 30 bins.
# Label the Y-Axis as "Frequency".

# %%
import pandas as pd
import matplotlib.pyplot as plt
cols = ["temperature", "humidity", "pressure", "radiation"]

# %%
# Create a histogram
df[cols].hist(bins=30)

# Label Y-Axis
plt.ylabel("Frequency")

# Show plot
plt.show()

# %% [markdown]
# ### Looking at the graphs we've just plotted, which of the following statements is true?
# A) radiation and pressure appear to be normally distributed.
#
# B) The maximum temperature is 15° Celsius.
#
# C) temperature and pressure appear to be normally distributed.
#
# D) B and C.
